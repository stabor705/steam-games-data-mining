# %%
from pandas import read_csv
from tqdm.notebook import tqdm
import random
import re
from collections import OrderedDict

# %%
df = read_csv("data/steam_games_data.csv")
df
# Out:
#                                name  steam_appid  \
# 0                    Counter-Strike           10
# 1             Team Fortress Classic           20
# 2                     Day of Defeat           30
# 3                Deathmatch Classic           40
# 4         Half-Life: Opposing Force           50
# ...                             ...          ...
# 10875                  Summer Crush      2163060
# 10876  Yet Another Zombie Survivors      2163330
# 10877                Tales of Spark      2165390
# 10878              Taora : Survival      2165470
# 10879        Mosaique Neko Waifus 5      2165610
#
#                                        short_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 10875  Summer Crush is a visual novel for adults wher...
# 10876  The Horde is coming but you're ready to fight ...
# 10877  &quot;Tales of Spark&quot; is a Hack &amp; Sla...
# 10878  Taora is an open world survival game with uniq...
# 10879  Unique hentai puzzle about flirting with cute ...
#
#                                     detailed_description  recommendations  \
# 0      Play the world's number 1 online action game. ...           162799
# 1      One of the most popular online action games of...             6688
# 2      Enlist in an intense brand of Axis vs. Allied ...             4326
# 3      Enjoy fast-paced multiplayer gaming with Death...             2349
# 4      Return to the Black Mesa Research Facility as ...            23052
# ...                                                  ...              ...
# 10875  <span class="bb_img_ctn"><video class="bb_img"...              383
# 10876  <p class="bb_paragraph" ><span class="bb_img_c...            10989
# 10877  <h1>Development Plan</h1><p><span class="bb_im...              554
# 10878  <span class="bb_img_ctn"><img class="bb_img" s...              305
# 10879  <span class="bb_img_ctn"><video class="bb_img"...             1315
#
#                                                  genres
# 0                                                Action
# 1                                                Action
# 2                                                Action
# 3                                                Action
# 4                                                Action
# ...                                                 ...
# 10875                                             Indie
# 10876          Action, Casual, Indie, RPG, Early Access
# 10877       Action, Adventure, Indie, RPG, Early Access
# 10878  Action, Adventure, RPG, Simulation, Early Access
# 10879                                       Casual, RPG
#
# [10880 rows x 6 columns]

# %%
def clean_description(description):
    regex_pattern = re.compile(r"<.*?>")

    # remove all html tags
    cleaned_description = re.sub(regex_pattern, "", description)
    # remove weird html artifacts like those: &lt;p&gt;
    cleaned_description = re.sub(r"&lt;.*?&gt;", " ", cleaned_description)
    cleaned_description = re.sub(r"&\w+?;", " ", cleaned_description)
    # remove tabs and new lines
    cleaned_description = cleaned_description.replace("\t", "").replace("\n", " ").strip()
    # remove multiple spaces
    cleaned_description = ' '.join(cleaned_description.split())
    return cleaned_description

# %%
import py3langid as langid

# remove duplicate steam_appid
df = df.drop_duplicates(subset="steam_appid")

def is_english(text):
    lang, _ = langid.classify(text)
    return lang == "en"

english_descriptions = df["short_description"].apply(is_english)
df = df[english_descriptions].reset_index(drop=True)
df
# Out:
#                                name  steam_appid  \
# 0                    Counter-Strike           10
# 1             Team Fortress Classic           20
# 2                     Day of Defeat           30
# 3                Deathmatch Classic           40
# 4         Half-Life: Opposing Force           50
# ...                             ...          ...
# 10607                  Summer Crush      2163060
# 10608  Yet Another Zombie Survivors      2163330
# 10609                Tales of Spark      2165390
# 10610              Taora : Survival      2165470
# 10611        Mosaique Neko Waifus 5      2165610
#
#                                        short_description  \
# 0      Play the world's number 1 online action game. ...
# 1      One of the most popular online action games of...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 10607  Summer Crush is a visual novel for adults wher...
# 10608  The Horde is coming but you're ready to fight ...
# 10609  &quot;Tales of Spark&quot; is a Hack &amp; Sla...
# 10610  Taora is an open world survival game with uniq...
# 10611  Unique hentai puzzle about flirting with cute ...
#
#                                     detailed_description  recommendations  \
# 0      Play the world's number 1 online action game. ...           162799
# 1      One of the most popular online action games of...             6688
# 2      Enlist in an intense brand of Axis vs. Allied ...             4326
# 3      Enjoy fast-paced multiplayer gaming with Death...             2349
# 4      Return to the Black Mesa Research Facility as ...            23052
# ...                                                  ...              ...
# 10607  <span class="bb_img_ctn"><video class="bb_img"...              383
# 10608  <p class="bb_paragraph" ><span class="bb_img_c...            10989
# 10609  <h1>Development Plan</h1><p><span class="bb_im...              554
# 10610  <span class="bb_img_ctn"><img class="bb_img" s...              305
# 10611  <span class="bb_img_ctn"><video class="bb_img"...             1315
#
#                                                  genres
# 0                                                Action
# 1                                                Action
# 2                                                Action
# 3                                                Action
# 4                                                Action
# ...                                                 ...
# 10607                                             Indie
# 10608          Action, Casual, Indie, RPG, Early Access
# 10609       Action, Adventure, Indie, RPG, Early Access
# 10610  Action, Adventure, RPG, Simulation, Early Access
# 10611                                       Casual, RPG
#
# [10612 rows x 6 columns]

# %%
# clean descriptions
df.loc[:, ["short_description"]] = df.apply(lambda row: clean_description(row["short_description"]), axis=1)
df.loc[:, ["detailed_description"]] = df.apply(lambda row: clean_description(row["detailed_description"]), axis=1)

# get rid of entries with empty descriptions
df = df[df["short_description"].str.len() > 0]
df = df[df["detailed_description"].str.len() > 0]

# get rid of entries with no genres
df = df[df["genres"].notna()]

# split genres into list
df["genres"] = df["genres"].apply(lambda x: x.split(", "))

# legal genres
genres = {"Indie", "Action", "Adventure", "Simulation", "RPG", "Strategy", "Casual"}

# filter genres to only legal ones
def filter_genres(genres_list):
    return [genre for genre in genres_list if genre in genres]

df.loc[:, ["genres"]] = df.apply(lambda row: filter_genres(row["genres"]), axis=1)

# get rid of entries with no legal genres
df = df[df["genres"].map(len) > 0]

df.reset_index(drop=True, inplace=True)

# remove the genre names from the descriptions
def remove_genre_names(description, genres_list):
    for genre in genres_list:
        description = re.sub(rf"\b{re.escape(genre)}\b", "", description, flags=re.IGNORECASE)
    # remove multiple spaces again
    description = ' '.join(description.split())
    return description

df.loc[:, ["short_description"]] = df.apply(lambda row: remove_genre_names(row["short_description"], row["genres"]), axis=1)
df.loc[:, ["detailed_description"]] = df.apply(lambda row: remove_genre_names(row["detailed_description"], row["genres"]), axis=1)

df
# Out:
#                                name  steam_appid  \
# 0                    Counter-Strike           10
# 1             Team Fortress Classic           20
# 2                     Day of Defeat           30
# 3                Deathmatch Classic           40
# 4         Half-Life: Opposing Force           50
# ...                             ...          ...
# 10408                  Summer Crush      2163060
# 10409  Yet Another Zombie Survivors      2163330
# 10410                Tales of Spark      2165390
# 10411              Taora : Survival      2165470
# 10412        Mosaique Neko Waifus 5      2165610
#
#                                        short_description  \
# 0      Play the world's number 1 online game. Engage ...
# 1      One of the most popular online games of all ti...
# 2      Enlist in an intense brand of Axis vs. Allied ...
# 3      Enjoy fast-paced multiplayer gaming with Death...
# 4      Return to the Black Mesa Research Facility as ...
# ...                                                  ...
# 10408  Summer Crush is a visual novel for adults wher...
# 10409  The Horde is coming but you're ready to fight ...
# 10410  Tales of Spark is a Hack Slash with an Eastern...
# 10411  Taora is an open world survival game with uniq...
# 10412  Unique hentai puzzle about flirting with cute ...
#
#                                     detailed_description  recommendations  \
# 0      Play the world's number 1 online game. Engage ...           162799
# 1      One of the most popular online games of all ti...             6688
# 2      Enlist in an intense brand of Axis vs. Allied ...             4326
# 3      Enjoy fast-paced multiplayer gaming with Death...             2349
# 4      Return to the Black Mesa Research Facility as ...            23052
# ...                                                  ...              ...
# 10408  Summer Crush is a visual novel for adults wher...              383
# 10409  You've had enough of hiding behind the barrica...            10989
# 10410  Development PlanFollow and join usFor inquirie...              554
# 10411  Taora is an island that is infested with zombi...              305
# 10412  Let's take a quick hike, shall we?How could yo...             1315
#
#                                      genres
# 0                                  [Action]
# 1                                  [Action]
# 2                                  [Action]
# 3                                  [Action]
# 4                                  [Action]
# ...                                     ...
# 10408                               [Indie]
# 10409          [Action, Casual, Indie, RPG]
# 10410       [Action, Adventure, Indie, RPG]
# 10411  [Action, Adventure, RPG, Simulation]
# 10412                         [Casual, RPG]
#
# [10413 rows x 6 columns]

# %%
df.to_csv("data/steam_games_data_cleaned.csv", index=False)

# %%
import nltk
import string

# convert to lowercase
df["short_description"] = df["short_description"].apply(lambda x: x.lower())
df["detailed_description"] = df["detailed_description"].apply(lambda x: x.lower())

# %%
# remove punctuation
df["short_description"] = df["short_description"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))
df["detailed_description"] = df["detailed_description"].apply(lambda x: x.translate(str.maketrans("", "", string.punctuation)))

# %%
# remove stopwords
nltk.download("punkt_tab")
nltk.download("stopwords")
EN_STOPWORDS = set(nltk.corpus.stopwords.words("english"))

def remove_stopwords(text):
    tokens = nltk.tokenize.word_tokenize(text)
    filtered_tokens = [token for token in tokens if token not in EN_STOPWORDS]
    return " ".join(filtered_tokens)

df["short_description"] = df["short_description"].apply(lambda x: remove_stopwords(x))
df["detailed_description"] = df["detailed_description"].apply(lambda x: remove_stopwords(x))
# Out:
# [nltk_data] Downloading package punkt_tab to /home/stachu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/stachu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()

nltk.download("wordnet")

def lemmatize_text(text):
    tokens = nltk.tokenize.word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return " ".join(lemmatized_tokens)

df["short_description"] = df["short_description"].apply(lambda x: lemmatize_text(x))
df["detailed_description"] = df["detailed_description"].apply(lambda x: lemmatize_text(x))
# Out:
# [nltk_data] Downloading package wordnet to /home/stachu/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df.to_csv("data/steam_games_data_deep_cleaned.csv", index=False)
